# %%
# !pip install biopython

# %%
from Bio import SeqIO
import re

# Define file name
file_name = "Organism_cDNA_FASTA.txt"

# Initialize variables

# Question 1
count_start_gtg = 0
genes_start_gtg = []

# Question 2
count_stop_codons = 0

# Question 3
longest_a_run = 0
longest_a_gene = None
longest_a_sequence = ""

# Question 4
count_poly_t = 0
genes_with_poly_t = []

# Question 5
motif = "AAGCTT"

count_motif_genes = 0
genes_with_motif = []


# Process FASTA file
for record in SeqIO.parse(file_name, "fasta"):

    sequence = str(record.seq).upper()
    gene_name = record.id

    # ********************************************************
    # Question 1:
    # Identify genes starting with "GTG"
    # ********************************************************

    if re.search(r"^GTG", sequence):

        count_start_gtg += 1
        genes_start_gtg.append(gene_name)


    # ********************************************************
    # Question 2:
    # Identify genes ending with stop codons
    # ********************************************************

    if re.search(r"(TAA|TAG|TGA)$", sequence):

        count_stop_codons += 1


    # ********************************************************
    # Question 3:
    # Find longest stretch of 4 or more consecutive "A"
    # ********************************************************

    a_run_matches = re.findall(r"A{4,}", sequence)

    if a_run_matches:

        max_a_run = max(a_run_matches, key=len)

        if len(max_a_run) > longest_a_run:

            longest_a_run = len(max_a_run)
            longest_a_gene = gene_name
            longest_a_sequence = max_a_run


    # ********************************************************
    # Question 4:
    # Find genes with 6 or more consecutive "T"
    # ********************************************************

    t_matches = re.findall(r"T{6,}", sequence)

    if t_matches:

        count_poly_t += 1

        genes_with_poly_t.append(
            f"{gene_name} ({', '.join(t_matches)})"
        )


    # ********************************************************
    # Question 5:
    # Find genes with one or more occurrences of motif
    # ********************************************************

    motif_matches = re.findall(motif, sequence)

    if motif_matches:

        count_motif_genes += 1

        genes_with_motif.append(
            f"{gene_name} ({len(motif_matches)} occurrence(s))"
        )


# ********************************************************
# Output Results
# ********************************************************

print("Question 1:")
print(f"Genes starting with 'GTG': {count_start_gtg}")
print("Gene Names:")
print(", ".join(genes_start_gtg))


print("\nQuestion 2:")
print(f"Genes ending with a stop codon: {count_stop_codons}")


print("\nQuestion 3:")
print(f"Gene with the longest consecutive 'A' stretch: {longest_a_gene}")
print(f"Longest stretch: {longest_a_sequence}")
print(f"Length of stretch: {longest_a_run}")


print("\nQuestion 4:")
print(f"Genes with 6 or more consecutive 'T': {count_poly_t}")
print("Gene Names and Matching Stretches:")

for gene in genes_with_poly_t:
    print(gene)


print("\nQuestion 5:")
print(f"Genes containing motif '{motif}': {count_motif_genes}")
print("Gene Names and Motif Counts:")

for gene in genes_with_motif:
    print(gene)
# Out:
# Question 1:
# Genes starting with 'GTG': 0
# Gene Names:
#
#
# Question 2:
# Genes ending with a stop codon: 62
#
# Question 3:
# Gene with the longest consecutive 'A' stretch: 2L52.1
# Longest stretch: AAAAAAAA
# Length of stretch: 8
#
# Question 4:
# Genes with 6 or more consecutive 'T': 15
# Gene Names and Matching Stretches:
# 4R79.1a (TTTTTT)
# 6R55.2 (TTTTTTTT)
# AC3.1 (TTTTTT)
# AC3.6 (TTTTTT)
# AC3.7 (TTTTTT, TTTTTT)
# AC3.8 (TTTTTT, TTTTTTT)
# AC7.2b (TTTTTT)
# AC8.3 (TTTTTT)
# AC8.10 (TTTTTT)
# AH6.1 (TTTTTT)
# AH6.6 (TTTTTT)
# AH6.8 (TTTTTTT, TTTTTT)
# AH6.14 (TTTTTT)
# AH9.1 (TTTTTT)
# AH10.4 (TTTTTTT)
#
# Question 5:
# Genes containing motif 'AAGCTT': 28
# Gene Names and Motif Counts:
# 3R5.1a (1 occurrence(s))
# 3R5.1b (1 occurrence(s))
# 4R79.1a (1 occurrence(s))
# AC3.2 (3 occurrence(s))
# AC3.3 (2 occurrence(s))
# AC3.4 (2 occurrence(s))
# AC3.5a (3 occurrence(s))
# AC3.5b (3 occurrence(s))
# AC3.7 (3 occurrence(s))
# AC7.1b (1 occurrence(s))
# AC7.2a (1 occurrence(s))
# AC7.2b (1 occurrence(s))
# AC8.3 (1 occurrence(s))
# AC8.10 (1 occurrence(s))
# AH6.6 (1 occurrence(s))
# AH6.7 (2 occurrence(s))
# AH6.11 (1 occurrence(s))
# AH6.14 (1 occurrence(s))
# AH9.1 (3 occurrence(s))
# AH9.4 (1 occurrence(s))
# AH9.6 (1 occurrence(s))
# AH10.1 (2 occurrence(s))
# AH10.2 (1 occurrence(s))
# AH10.4 (1 occurrence(s))
# B0001.2 (1 occurrence(s))
# B0001.3a (2 occurrence(s))
# B0001.3b (2 occurrence(s))
# B0001.4 (2 occurrence(s))
