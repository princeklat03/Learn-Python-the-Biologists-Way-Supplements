# %%
{
    key1: value1,
    key2: value2,
    ket3: value3
}

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
dict_one = {}
print(dict_one)               # Output: {}
print(type(dict_one))      # Output: <class 'dict'>
# Out:
# {}
# <class 'dict'>

# %%
dict_two = dict()
print(dict_two)               # Output: {}
print(type(dict_two))      # Output: <class 'dict'>
# Out:
# {}
# <class 'dict'>

# %%
dict_three = {
    "gene_name": "Tp53",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome"
}
print(dict_three)           # {‘gene_name’: ‘TP53’, ‘location’: ‘17p13.1’, ‘disease’: ‘Li-Fraumeni syndrome’}
print(type(dict_three))  # <class ‘dict’>
# Out:
# {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome'}
# <class 'dict'>

# %%
dict_four = dict(
    gene_name="Tp53",
    location="17p13.1",
    disease="Li-Fraumeni syndrome"
)
print(dict_four)
# Out:
# {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome'}

# %%
keys = ["gene_name", "location", "disease"]
values = ["Tp53", "17p13.1", "Li-Fraumeni syndrome"]

# Combine lists using zip
zipped_lists = zip(keys, values)

# Convert to dictionary
dict_five = dict(zipped_lists)
print(dict_five)
# Out:
# {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome'}

# %%
dict_six = {
    "gene_name": "TP53",
    "expression": 120
}
print(dict_six)
# Out:
# {'gene_name': 'TP53', 'expression': 120}

# %%
dict_seven = {
    "gene_name": "TP53",
    "expression_values": [12.0, 13.5, 11.8]
}
print(dict_seven)
# Out:
# {'gene_name': 'TP53', 'expression_values': [12.0, 13.5, 11.8]}

# %%
dict_eight = {
    "gene_name": "MYC",
    "gene_name": "Tp53"
}
print(dict_eight)    #Output: {'gene_name': 'Tp53'}
# Out:
# {'gene_name': 'Tp53'}

# %%
dict_nine = {
    "gene_name_1": "MYC",
    "gene_name_2": "MYC",
    "gene_name_3": "MYC"
}
print(dict_nine)
# Out:
# {'gene_name_1': 'MYC', 'gene_name_2': 'MYC', 'gene_name_3': 'MYC'}

# %%
print("Length of the dictionary is:", len(dict_nine))
# Out:
# Length of the dictionary is: 3

# %%
dict_ten = dict_nine.copy()

# %%
dict_eleven = dict_nine

# %%
print("ID of dict_nine:", id(dict_nine))
print("ID of dict_ten:", id(dict_ten))
print("ID of dict_eleven:", id(dict_eleven))
# Out:
# ID of dict_nine: 139323176459008
# ID of dict_ten: 139323176644992
# ID of dict_eleven: 139323176459008

# %%
dict_nine_keys = dict_nine.keys()
print(dict_nine_keys)
# Out:
# dict_keys(['gene_name_1', 'gene_name_2', 'gene_name_3'])

# %%
dict_nine_values = dict_nine.values()
print(dict_nine_values)
# Out:
# dict_values(['MYC', 'MYC', 'MYC'])

# %%
keys_list = list(dict_nine.keys())
values_list = list(dict_nine.values())

print(keys_list)
print(values_list)
# Out:
# ['gene_name_1', 'gene_name_2', 'gene_name_3']
# ['MYC', 'MYC', 'MYC']

# %%
dict_from_lists = dict(zip(keys_list, values_list))

# %%
dict_one = {"a": 1, "b": 2, "c": 3}

# %%
my_list = ["a", "b", "c"]

# %%
my_list[1]    # Output: ‘b’
# Out:
# 'b'

# %%
# dictionary_name[key]

# %%
dict_one = {"a": 1, "b": 2, "c": 3}

print(dict_one["a"])    # Output: 1
print(dict_one["b"])    # Output: 2
# Out:
# 1
# 2

# %%
dict_nine = {
    "gene_name": "MYC",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome",
    "expression": 120
}

# %%
dict_nine["location"]
# Out:
# '17p13.1'

# %%
dict_nine["expression"]
# Out:
# 120

# %%
dict_nine["expression_one"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3022/2809568887.py in <cell line: 0>()
# ----> 1 dict_nine["expression_one"]
#
# KeyError: 'expression_one'

# %%
# dictionary_name.get(key, default_value)

# %%
dict_nine.get("expression_one", "")
# Out:
# ''

# %%
dict_nine.get("expression_one", "Key does not exist")
# Out:
# 'Key does not exist'

# %%
dict_nine.get("expression", "Key does not exist")	#Output: 120
# Out:
# 120

# %%
# dict_name[key]

# %%
# dict_name.get(key, default_value)

# %%
dict_one = {"a": 1, "b": 2, "c": 3}

# %%
dict_three = {
    "gene_name": "Tp53",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome"
}

# %%
# dictionary_name[new_key] = value

# %%
dict_three["expression"] = 120
print(dict_three)
# Out:
# {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome', 'expression': 120}

# %%
dict_three["expression"] = 150
print(dict_three)
# Out:
# {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}

# %%
# dictionary[key] = value

# %%
list_one = ["gene_name", "location", "disease"]

# %%
print("Before:", list_one)
list_one[1] = "Location"
print("After:", list_one)
# Out:
# Before: ['gene_name', 'location', 'disease']
# After: ['gene_name', 'Location', 'disease']

# %%
list_one [3]= "expression"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3022/171385319.py in <cell line: 0>()
# ----> 1 list_one [3]= "expression"
#
# IndexError: list assignment index out of range

# %%
list_one.append("expression")
print(list_one)
# Out:
# ['gene_name', 'Location', 'disease', 'expression']

# %%
string_one = "abc"
for i in string_one:
    print(i)
# Out:
# a
# b
# c

# %%
my_list = ["a", "b", "c"]
for item in my_list:
    print(item)
# Out:
# a
# b
# c

# %%
my_tuple = ["a", "b", "c"]
for item in my_tuple:
    print(item)
# Out:
# a
# b
# c

# %%
dict_three = {
    "gene_name": "Tp53",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome",
    "expression": 150
}

# %%
# for key in <dictionary_name>.keys():
#   print(key)

# %%
for key in dict_three.keys():
    print(key)
# Out:
# gene_name
# location
# disease
# expression

# %%
# for value in <dictionary_name>.values():
#   print(value)

# %%
for value in dict_three.values():
    print(value)
# Out:
# Tp53
# 17p13.1
# Li-Fraumeni syndrome
# 150

# %%
# for key, value in dictionary_name.items():
#   print(key, ":", value)

# %%
for key, value in dict_three.items():
    print(key, ":", value)
# Out:
# gene_name : Tp53
# location : 17p13.1
# disease : Li-Fraumeni syndrome
# expression : 150

# %%
dict3 = {
    "gene_name": "Tp53",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome",
    "expression": 150
}

# %%
dict3_copy = dict3.copy()

# %%
# value_deleted = dict3_copy.pop("<key>")

# %%
print("Before:", dict3_copy)
value_deleted = dict3_copy.pop("location")
print("Deleted Value:", value_deleted)
print("After:", dict3_copy)
# Out:
# Before: {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}
# Deleted Value: 17p13.1
# After: {'gene_name': 'Tp53', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}

# %%
# dict3_copy = dict3.copy()
# key_deleted, value_deleted = dict3_copy.popitem()

# %%
print("Before:", dict3_copy)
key_deleted, value_deleted = dict3_copy.popitem()
print("Deleted:", key_deleted, value_deleted)
print("After:", dict3_copy)
# Out:
# Before: {'gene_name': 'Tp53', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}
# Deleted: expression 150
# After: {'gene_name': 'Tp53', 'disease': 'Li-Fraumeni syndrome'}

# %%
# del dict3_copy["<key>"]

# %%
dict3_copy = dict3.copy()
print("Before:", dict3_copy)
del dict3_copy["location"]
print("After:", dict3_copy)
# Out:
# Before: {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}
# After: {'gene_name': 'Tp53', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}

# %%
dict3_copy = dict3.copy()
print("Before:", dict3_copy)
dict3_copy.clear()
print("After:", dict3_copy)
# Out:
# Before: {'gene_name': 'Tp53', 'location': '17p13.1', 'disease': 'Li-Fraumeni syndrome', 'expression': 150}
# After: {}

# %%
dict3_copy = dict3.copy()
del dict3_copy
print(dict3_copy)    # Raises NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3022/2659663915.py in <cell line: 0>()
#       1 dict3_copy = dict3.copy()
#       2 del dict3_copy
# ----> 3 print(dict3_copy)    # Raises NameError
#
# NameError: name 'dict3_copy' is not defined

# %%
dict10 = {
    "gene_name": "Tp53",
    "location": "17p13.1",
    "disease": "Li-Fraumeni syndrome",
    "expression": 200
}

# %%
keys_to_delete = ["location", "expression"]

dict11 = {
        key: value
        for key, value in dict10.items()
        if key not in keys_to_delete
}

print(dict11)
# Out:
# {'gene_name': 'Tp53', 'disease': 'Li-Fraumeni syndrome'}
