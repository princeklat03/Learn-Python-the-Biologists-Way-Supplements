# %%
"""
In-class Notebook for Chapter 13
Learn Python the Biologist's Way

This notebook contains the Python code examples
demonstrated throughout Chapter 13.

The notebook is provided as a companion resource
to help readers practice, experiment, and reproduce
the examples discussed in the book.

The book purchase link and additional resources are
available on the GitHub repository landing page.

Author: Dr. Prince Kumar Lat
"""

print('Welcome to Chapter 13')

# %%
dna = "ATTGGGCC"

reverse_comp_dna = dna.replace("A", "t")
reverse_comp_dna = reverse_comp_dna.replace("T", "a")
reverse_comp_dna = reverse_comp_dna.replace("G", "c")
reverse_comp_dna = reverse_comp_dna.replace("C", "g")

reverse_comp_dna = reverse_comp_dna.upper()
reverse_comp_dna = reverse_comp_dna[::-1]

print(reverse_comp_dna)

# %%
# def function_name(parameters):
#     function_body
#     return value

# %%
def do_reverse_complement(input_dna):
    reverse_comp_dna = input_dna.replace("A", "t")
    reverse_comp_dna = reverse_comp_dna.replace("T", "a")
    reverse_comp_dna = reverse_comp_dna.replace("G", "c")
    reverse_comp_dna = reverse_comp_dna.replace("C", "g")

    reverse_comp_dna = reverse_comp_dna.upper()
    reverse_comp_dna = reverse_comp_dna[::-1]

    return reverse_comp_dna

# %%
dna1 = "ATTGGGCC"
dna2 = "ATCGTTAG"

result1 = do_reverse_complement(dna1)
result2 = do_reverse_complement(dna2)

print(result1)
print(result2)

# %%
# def function_name(parameters):
#     function body
#     return value

# %%
def do_reverse_complement_no_return(input_dna):
    reverse_comp_dna = input_dna.replace("A", "t")
    reverse_comp_dna = reverse_comp_dna.replace("T", "a")
    reverse_comp_dna = reverse_comp_dna.replace("G", "c")
    reverse_comp_dna = reverse_comp_dna.replace("C", "g")

    reverse_comp_dna = reverse_comp_dna.upper()
    reverse_comp_dna = reverse_comp_dna[::-1]

    print(reverse_comp_dna)

# %%
do_reverse_complement_no_return("ATTGGGCC")

# %%
def empty_function_demo():
    pass

# %%
import random

def generate_random_dna():
    nucleotides = ["A", "T", "G", "C"]
    dna_sequence = "".join(random.choice(nucleotides) for i in range(10))
    return dna_sequence

# %%
dna1 = generate_random_dna()
dna2 = generate_random_dna()

print(dna1)
print(dna2)

# %%
# !pip install biopython
from Bio.SeqUtils import gc_fraction

# %%
def calculate_and_compare_gc(dna_seq1, dna_seq2, decimals):
    gc1 = round(gc_fraction(dna_seq1), decimals)
    gc2 = round(gc_fraction(dna_seq2), decimals)

    if gc1 > gc2:
        comparison = "greater"
    else:
        comparison = "less"

    return gc1, gc2, comparison

# %%
dna1 = generate_random_dna()
dna2 = generate_random_dna()

gc1, gc2, result = calculate_and_compare_gc(dna1, dna2, 2)

print(f"GC content DNA1: {gc1:<8} GC content DNA2: {gc2:<8}")
print(f"DNA1GC content is {result} than DNA2")

# %%
# def function_name(arg1, arg2, arg3):
#     # block of code
#     return out1, out2, out3

# %%
# def demo_function(arg1, arg2, arg3):
#     return out1, out2, out3

# %%
# x, y, z = demo_function(a, b, c)

# %%
def calculate_gc(dna_seq1, dna_seq2):
    pass

# %%
calculate_gc("ATCG", "GGTA")

# %%
def calculate_and_compare_gc(dna_seq1, dna_seq2, sig_dec=2):
    gc1 = round(gc_fraction(dna_seq1), sig_dec)
    gc2 = round(gc_fraction(dna_seq2), sig_dec)
    return gc1, gc2

# %%
def func(a=2, b):
    pass

# %%
def func(a, b=2):
    pass

# %%
gc1, gc2 = calculate_and_compare_gc(dna1, dna2)

# %%
gc1, gc2 = calculate_and_compare_gc(dna1, dna2, sig_dec=3)

# %%
# *args

# %%
def average_gene_expression(*args):
    sum_expression = 0
    count = 0

    for expression_value in args:
        sum_expression += expression_value
        count += 1

    average_expression = sum_expression / count
    return round(average_expression, 2)

# %%
avg1 = average_gene_expression(120, 140)
print(avg1)

# %%
avg2 = average_gene_expression(120, 140, 125)
print(avg2)

# %%
avg3 = average_gene_expression(123, 91, 234, 56, 78, 77, 89, 101, 110, 95)
print(avg3)

# %%
def average_gene_expression_kw(**kwargs):
    sum_expression = 0
    count = 0

    for exp_id, expression_value in kwargs.items():
        sum_expression += expression_value
        count += 1

    average_expression = sum_expression / count
    return round(average_expression, 2)

# %%
avg1 = average_gene_expression_kw(
    experiment1=120,
    experiment2=130
)
print(avg1)

# %%
avg2 = average_gene_expression_kw(
    experiment1=120,
    experiment2=130,
    experiment3=150,
    experiment4=144,
    experiment5=116,
)
print(avg2)
