# %%
"""
In-class Notebook for Chapter 4
Learn Python the Biologist's Way

This notebook contains the Python code examples
demonstrated throughout Chapter 4.

The notebook is provided as a companion resource
to help readers practice, experiment, and reproduce
the examples discussed in the book.

The book purchase link and additional resources are
available on the GitHub repository landing page.

Author: Dr. Prince Kumar Lat
"""

print('Welcome to Chapter 4')

# %%
num1 = 2
num3 = 4.4

print(type(num1))  # <class 'int'>
print(type(num3))  # <class 'float'>

# %%
num1 = 2
num2 = 4
sum_1_2 = num1 + num2
print(sum_1_2)

# %%
num3 = 2.4
num4 = 4.0
sum_3_4 = num3 + num4
print(sum_3_4)

num5 = 2
num6 = 4.3
sum_5_6 = num5 + num6
print(sum_5_6)

# %%
diff_5_6 = num5 - num6
print(diff_5_6)

# %%
mul_5_6 = num5 * num6
print(mul_5_6)

# %%
div_5_6 = num5 / num6
print(div_5_6)

# %%
quotient = 6 // 4
print(quotient)

# %%
remainder = 6 % 4
print(remainder)

# %%
# Using the complex() function
comp_a = complex(2, 3)
print(comp_a)

# Direct notation
comp_b = 2 + 3j
print(comp_b)

# %%
a = 3
b = 5
c = 7
d = 0
e = 3

print(a > d)
print(e < c)
print(c < e)
print(a == e)

# %%
a = 2
power_result = a ** 4
print(power_result)

power_result = a ** 5
print(power_result)

# %%
x = 10
y = 3
print(x // y = 3)

# %%
print(5 / 2)

# %%
num = 2**3
print(num)

# %%
value = 10 % 0
print(value)

# %%
print(7 // 2.0)

# %%
a = 10
b = 4
print(a % b)

# %%
print(3 * 2 + 4)
