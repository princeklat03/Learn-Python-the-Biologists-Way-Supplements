# %%
num1 = 2
num3 = 4.4

print(type(num1))  # <class 'int'>
print(type(num3))  # <class 'float'>
# Out:
# <class 'int'>
# <class 'float'>

# %%
num1 = 2
num2 = 4
sum_1_2 = num1 + num2
print(sum_1_2)  # 6
# Out:
# 6

# %%
num3 = 2.4
num4 = 4.0
sum_3_4 = num3 + num4
print(sum_3_4)  # 6.4

num5 = 2
num6 = 4.3
sum_5_6 = num5 + num6
print(sum_5_6)  # 6.3
# Out:
# 6.4
# 6.3

# %%
diff_5_6 = num5 - num6
print(diff_5_6)
# Out:
# -2.3

# %%
mul_5_6 = num5 * num6
print(mul_5_6)
# Out:
# 8.6

# %%
div_5_6 = num5 / num6
print(div_5_6)
# Out:
# 0.46511627906976744

# %%
quotient = 6 // 4
print(quotient)  # 1
# Out:
# 1

# %%
remainder = 6 % 4
print(remainder)  # 2
# Out:
# 2

# %%
# Using the complex() function
comp_a = complex(2, 3)
print(comp_a)    # (2+3j)

# Direct notation
comp_b = 2 + 3j
print(comp_b)    # (2+3j)
# Out:
# (2+3j)
# (2+3j)

# %%
a = 3
b = 5
c = 7
d = 0
e = 3

print(a > d)     # True
print(e < c)     # True
print(c < e)     # False
print(a == e)   # True
# Out:
# True
# True
# False
# True

# %%
a = 2
power_result = a ** 4
print(power_result)  # 16

power_result = a ** 5
print(power_result)  # 32
# Out:
# 16
# 32

# %%
x = 10
y = 3
print(x // y = 3)
# Out:
#   File "/tmp/ipykernel_26635/3555256435.py", line 3
#     print(x // y = 3)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
print(5 / 2)
# Out:
# 2.5

# %%
num = 2**3
print(num)
# Out:
# 1

# %%
value = 10 % 0
print(value)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_26635/1090338192.py in <cell line: 0>()
# ----> 1 value = 10 % 0
#       2 print(value)
#
# ZeroDivisionError: integer modulo by zero

# %%
print(7 // 2.0)
# Out:
# 3.0

# %%
a = 10
b = 4
print(a % b)
# Out:
# 2

# %%
print(3 * 2 + 4)
# Out:
# 10
