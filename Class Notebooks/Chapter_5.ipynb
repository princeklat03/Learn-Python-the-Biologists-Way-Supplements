# %%
"Hello, World!"  # String in double quotes
'Hello, World!'  # String in single quotes
# Out:
# 'Hello, World!'

# %%
first_string = "We will study the basics of the string data type in the class."
second_string = 'Here we will study about string manipulation methods.'

print(first_string)
print(second_string)
# Out:
# We will study the basics of the string data type in the class.
# Here we will study about string manipulation methods.

# %%
third_string = "We will highlight the word 'string' here."
print(third_string)
# Out:
# We will highlight the word 'string' here.

# %%
fourth_string = 'We will highlight the word "string" here.'
print(fourth_string)
# Out:
# We will highlight the word "string" here.

# %%
num_a = 23       # Integer
num_b = "23"     # String containing digits

print(type(num_a))  # <class 'int'>
print(type(num_b))  # <class 'str'>
# Out:
# <class 'int'>
# <class 'str'>

# %%
num_a = 23
num_a_str = str(num_a)

print(num_a_str)                # "23"
print(type(num_a_str))    # <class 'str'>
# Out:
# 23
# <class 'str'>

# %%
num_string = "45"
num_int = int(num_string)

print(num_int)             # 45
print(type(num_int))    # <class 'int'>
# Out:
# 45
# <class 'int'>

# %%
temp_string = "python"
temp_int = int(temp_string)   # Raises ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13087/881092948.py in <cell line: 0>()
#       1 temp_string = "python"
# ----> 2 temp_int = int(temp_string)   # Raises ValueError
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
protein_seq = "VLSPADKTNVK"

# %%
length = len(protein_seq)
print(length)      # 11
# Out:
# 11

# %%
print(protein_seq[0])     # V (first amino acid)
print(protein_seq[2])     # S (third amino acid)
print(protein_seq[-1])    # K (last amino acid)
# Out:
# V
# S
# K

# %%
print(protein_seq[1:6])      # LSPAD
# Out:
# LSPAD

# %%
print(protein_seq[1:6:2])      # LPD
print(protein_seq[1:6:3])      # LA
# Out:
# LPD
# LA

# %%
print(protein_seq[::-1])      # KVN…V
# Out:
# KVNTKDAPSLV

# %%
dna_frag1 = "ATCG"
dna_frag2 = "TGGGC"

full_dna = dna_frag1 + dna_frag2
print(full_dna)   # ATCGTGGGC
# Out:
# ATCGTGGGC

# %%
repeat_seq = "GGGGCC "
repeat_length = 4

# Method 1: Typecasting with +
formatted = " ("+ repeat_seq +") " + str(repeat_length)
print(formatted)     # (GGGGCC)4

# Method 2: f-string
formatted_f = f"({repeat_seq}){repeat_length}"
print(formatted_f)   # (GGGGCC)4
# Out:
#  (GGGGCC ) 4
# (GGGGCC )4

# %%
dna_length = 5423
message = "The DNA sequence length is" + str(dna_length) + "base pairs."
print(message)
# Out:
# The DNA sequence length is5423base pairs.

# %%
dna_length = 5423
message = f"The DNA sequence length is {dna_length} base pairs."
print(message)
# Out:
# The DNA sequence length is 5423 base pairs.

# %%
DNA_upper = "ATGGCCCG"
DNA_lower = "atggcccggt"

# %%
DNA_upper = "ATGGCCCG"
DNA_lowered = DNA_upper.lower()
print(DNA_lowered)   # atggccc
# Out:
# atggcccg

# %%
DNA_lower = "atggccc"
DNA_uppercased = DNA_lower.upper()
print(DNA_uppercased)   # ATGGCCC
# Out:
# ATGGCCC

# %%
simulation_name = "molecular dynamics simulation"
formatted_title = simulation_name.title()
print(f"Before: '{simulation_name}' | After: '{formatted_title}' ")
# Out:
# Before: ‘molecular dynamics simulation’ | After: ‘Molecular Dynamics Simulation’

# %%
Before: 'i am enjoying python programming for bioinformatics.'
After: 'I am enjoying python programming for bioinformatics.'

# %%
description = "i am enjoying python programming for bioinformatics."
formatted_sentence = description.capitalize()
print(f"Before: '{description}' | After: '{formatted_sentence}' ")
# Out:
# Before: 'i am enjoying python programming for bioinformatics.' | After: 'I am enjoying python programming for bioinformatics.'

# %%
# Wild type protein sequence
protein = "MWDWQWEP"

# Mutant 1: = Replace all tryptophan (W) with methionine (M)
mutant1 = protein.replace("W", "M")
print(mutant1)     # MMDMQMEP
# Out:
# MMDMQMEP

# %%
# Mutant 2: = Replace only first occurrence of W
mutant2 = protein.replace("W", "M", 1)
print(mutant2)     # MMDWQWEP
# Out:
# MMDWQWEP

# %%
# Mutant 3: = Replace the first two occurrences of W
mutant3 = protein.replace("W", "M", 2)
print(mutant3)     # MMDMQWEP
# Out:
# MMDMQWEP

# %%
sentence = "I am learning Python to analyse DNA and biological data."

# %%
modified = sentence.replace("analyse", "analyze")
print(modified)
# I am learning Python to analyze DNA and biological data.
# Out:
# I am learning Python to analyze DNA and biological data.

# %%
sentence1 = "Python for biologists"
sentence2 = "Python for biologists and python for beginners"

print(sentence1.find("Python"))    # Output: 0
print(sentence2.find("Python"))    # Output: 0
# Out:
# 0
# 0

# %%
protein = "VLPADWVWLP"

# Find the first occurrence of proline (P)
pro_occurrence = protein.find("P")
print(pro_occurrence)    # Output: 2
# Out:
# 2

# %%
print(protein.find("MC"))   # Output: -1
# Out:
# -1

# %%
motif_occurence = protein.find("AD")
print(motif_occurence)    # Output: 3
# Out:
# 3

# %%
# Find Tryptophan (W)
w_occurrence = protein.find("W")
print(w_occurrence)     # Output: 5
# Out:
# 5

# %%
sentence = "Python for biologists and Python for beginners"
print(sentence.count("Python"))    # Output: 2
# Out:
# 2

# %%
protein = "VLPADWVWLP"

# Count the number of Tryptophans (W)
w_count = protein.count("W")
print(w_count)    # Output: 2
# Out:
# 2

# %%
print(protein.count("Z"))      # Output: 0
# Out:
# 0

# %%
# A sentence about biology
string_to_split = "Biology is interesting, I am using python to analyze biological data."

# Splitting by spaces (default separator)
attempt1 = string_to_split.split()
print(attempt1)
# Out:
# ['Biology', 'is', 'interesting,', 'I', 'am', 'using', 'python', 'to', 'analyze', 'biological', 'data.']

# %%
attempt2 = string_to_split.split(",")
print(attempt2)
# Out:
# ['Biology is interesting', ' I am using python to analyze biological data.']

# %%
# Recombine attempt1 using a space (restore original sentence)
recombine1 = " ".join(attempt1)
print(recombine1)
# Out:
# Biology is interesting, I am using python to analyze biological data.

# %%
# Recombine attempt2 using a space (restore original sentence)
recombine2 = "; ".join(attempt2)
print(recombine2)
# Out:
# Biology is interesting;  I am using python to analyze biological data.

# %%
temp1 = "Python is fun"
temp2 = "   Python is fun…." # spaces before and after

# %%
temp2.replace(" ", "")
# Out:
# 'Pythonisfun….'

# %%
temp2_cleaned = temp2.strip()
print(temp2_cleaned)
# Out:
# Python is fun….

# %%
seq = ";ATGCGTAA;"
print(seq.strip(";"))
# Out:
# ATGCGTAA

# %%
seq = " ATGCGTAA "

print(seq.lstrip())     # Removes only leading spaces
print(seq.rstrip())     # Removes only trailing spaces
# Out:
# ATGCGTAA
#  ATGCGTAA

# %%
# Input DNA sequence
DNA = "ATCG"

# Stepwise replacement using lowercase placeholders
seq = DNA.replace("A", "t")
seq = seq.replace("T", "a")
seq = seq.replace("C", "g")
seq = seq.replace("G", "c")

# Convert to uppercase
complement = seq.upper()

# Reverse the string to obtain reverse complement
reverse_complement = complement[::-1]

print("Original DNA:                  ", DNA)
print("Complement:                    ", complement)
print("Reverse complement:            ", reverse_complement)
# Out:
# Original DNA:                   ATCG
# Complement:                     TAGC
# Reverse complement:             CGAT

# %%
# Input DNA sequence
DNA = "ATCGATCGGGCCT"

# Count G’s and C’s
count_g = DNA.count("G")
count_c = DNA.count("C")

# Total GC count
gc_count = count_g + count_c

# Total length of the DNA sequence
total_length = len(DNA)

# GC content as a percentage
gc_content = (gc_count / total_length) * 100

# Round to two decimal places
gc_content = round(gc_content, 2)
print(f"GC content of this DNA fragment is {gc_content}%")
# Out:
# GC content of this DNA fragment is 61.54%
