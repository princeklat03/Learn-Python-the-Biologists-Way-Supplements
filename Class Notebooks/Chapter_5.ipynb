# %%
"""
In-class Notebook for Chapter 5
Learn Python the Biologist's Way

This notebook contains the Python code examples
demonstrated throughout Chapter 5.

The notebook is provided as a companion resource
to help readers practice, experiment, and reproduce
the examples discussed in the book.

The book purchase link and additional resources are
available on the GitHub repository landing page.

Author: Dr. Prince Kumar Lat
"""

print('Welcome to Chapter 5')

# %%
"Hello, World!"
'Hello, World!'

# %%
first_string = "We will study the basics of the string data type in the class."
second_string = 'Here we will study about string manipulation methods.'

print(first_string)
print(second_string)

# %%
third_string = "We will highlight the word 'string' here."
print(third_string)

# %%
fourth_string = 'We will highlight the word "string" here.'
print(fourth_string)

# %%
num_a = 23
num_b = "23"

print(type(num_a))
print(type(num_b))

# %%
num_a = 23
num_a_str = str(num_a)

print(num_a_str)
print(type(num_a_str))

# %%
num_string = "45"
num_int = int(num_string)

print(num_int)
print(type(num_int))

# %%
temp_string = "python"
temp_int = int(temp_string)

# %%
protein_seq = "VLSPADKTNVK"

# %%
length = len(protein_seq)
print(length)

# %%
print(protein_seq[0])
print(protein_seq[2])
print(protein_seq[-1])

# %%
print(protein_seq[1:6])

# %%
print(protein_seq[1:6:2])
print(protein_seq[1:6:3])

# %%
print(protein_seq[::-1])

# %%
dna_frag1 = "ATCG"
dna_frag2 = "TGGGC"

full_dna = dna_frag1 + dna_frag2
print(full_dna)

# %%
repeat_seq = "GGGGCC"
repeat_length = 4


formatted = "("+ repeat_seq +")" + str(repeat_length)
print(formatted)


formatted_f = f"({repeat_seq}){repeat_length}"
print(formatted_f)

# %%
dna_length = 5423
message = "The DNA sequence length is " + str(dna_length) + " base pairs."
print(message)

# %%
dna_length = 5423
message = f"The DNA sequence length is {dna_length} base pairs."
print(message)

# %%
DNA_upper = "ATGGCCCG"
DNA_lower = "atggccc"

# %%
DNA_upper = "ATGGCCCG"
DNA_lowered = DNA_upper.lower()
print(DNA_lowered)

# %%
DNA_lower = "atggccc"
DNA_uppercased = DNA_lower.upper()
print(DNA_uppercased)

# %%
simulation_name = "molecular dynamics simulation"
formatted_title = simulation_name.title()
print(f"Before: '{simulation_name}' | After: '{formatted_title}' ")

# %%
description = "i am enjoying python programming for bioinformatics."
formatted_sentence = description.capitalize()
print(f"Before: '{description}' | After: '{formatted_sentence}' ")

# %%
protein = "MWDWQWEP"

mutant1 = protein.replace("W", "M")
print(mutant1)

# %%
mutant2 = protein.replace("W", "M", 1)
print(mutant2)

# %%
mutant3 = protein.replace("W", "M", 2)
print(mutant3)

# %%
sentence = "I am learning Python to analyse DNA and biological data."

# %%
modified = sentence.replace("analyse", "analyze")
print(modified)

# %%
sentence1 = "Python for biologists"
sentence2 = "Python for biologists and python for beginners"

print(sentence1.find("Python"))
print(sentence2.find("Python"))

# %%
protein = "VLPADWVWLP"

pro_occurrence = protein.find("P")
print(pro_occurrence)

# %%
motif_occurence = protein.find("AD")
print(motif_occurence)

# %%
print(protein.find("MC"))

# %%
w_occurrence = protein.find("W")
print(w_occurrence)

# %%
sentence = "Python for biologists and Python for beginners"
print(sentence.count("Python"))

# %%
protein = "VLPADWVWLP"

w_count = protein.count("W")
print(w_count)

# %%
print(protein.count("Z"))

# %%
string_to_split = "Biology is interesting, I am using python to analyze biological data."

attempt1 = string_to_split.split()
print(attempt1)

# %%
attempt2 = string_to_split.split(",")
print(attempt2)

# %%
recombine1 = " ".join(attempt1)
print(recombine1)

# %%
recombine2 = "; ".join(attempt2)
print(recombine2)

# %%
temp1 = "Python is fun"
temp2 = "   Python is fun   "

# %%
temp2.replace(" ", "")

# %%
temp2_cleaned = temp2.strip()
print(temp2_cleaned)

# %%
seq = ";ATGCGTAA;"
print(seq.strip(";"))

# %%
seq = "   ATGCGTAA   "

print(seq.lstrip())
print(seq.rstrip())

# %%
DNA = "ATCG"

seq = DNA.replace("A", "t")
seq = seq.replace("T", "a")
seq = seq.replace("C", "g")
seq = seq.replace("G", "c")

complement = seq.upper()

reverse_complement = complement[::-1]

print("Original DNA:                                              ", DNA)
print("Complement:                                               ", complement)
print("Reverse complement:                                 ", reverse_complement)

# %%
DNA = "ATCGATCGGGCCT"

count_g = DNA.count("G")
count_c = DNA.count("C")

gc_count = count_g + count_c

total_length = len(DNA)

gc_content = (gc_count / total_length) * 100

gc_content = round(gc_content, 2)
print(f"GC content of this DNA fragment is {gc_content}%")
