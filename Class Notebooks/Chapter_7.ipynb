# %%
# Example of a list
my_list = [1,2,3,4]

# %%
mixed_list = [1, "Python", 3.14, True]
print(mixed_list)  # Output: [1, 'Python', 3.14, True]
# Out:
# [1, 'Python', 3.14, True]

# %%
# Method 1: Using square brackets
list1 = []

# Method 2: Using square brackets
list2 = list()

print(list1)    # []
print(list2)    # []
# Out:
# []
# []

# %%
list3 = [1, 2, 4.5, "Python", True]
print(list3)   # Output: [1, 2, 4.5, 'Python', True]
# Out:
# [1, 2, 4.5, 'Python', True]

# %%
a = range(6)               # Generates numbers 0,1,2,3,4,5
list4 = list(a)
print(list4)                  # [0,1,2,3,4,5]
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list5 = list(range(2, 10, 2))
print(list5)                  # [2, 4, 6, 8]
# Out:
# [2, 4, 6, 8]

# %%
list6 = [x/2 for x in range(6)]
print(list6) # Output: [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]

# %%
tuple1 = (1, 2, 3, 4)
print(tuple1) # [1, 2, 3, 4]
# Out:
# (1, 2, 3, 4)

# %%
tuple1 = ()
tuple2 = tuple()

# %%
tuple3 = (1, 2, 3, "Biology", False)

# %%
t = (3,)
print(type(t))    # <class 'tuple'>

t_wrong = (3)
print(type(t_wrong))     # <class 'int'>
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
tuple4 = tuple(range(6))
print(tuple4)     # [0,1,2,3,4,5]
# Out:
# (0, 1, 2, 3, 4, 5)

# %%
list3 = [1, 2, 4.5, "Python", True]

# Access by index (by default index starts from 0)
print(list3[1])           # 2
print(list3[3])           # Python
# Out:
# 2
# Python

# %%
# Update an element (Mutation)
list3[2] = 5.5
print(list3) # [1, 2, 5.5, ‘Python’, True]
# Out:
# [1, 2, 5.5, 'Python', True]

# %%
tuple5 = (1, 2, 3, 4, 5)
print(tuple5[2])      # 3
# Out:
# 3

# %%
tuple5[2] = 10  # Error: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4693/1304901731.py in <cell line: 0>()
# ----> 1 tuple5[2] = 10  # Error: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Creating a non-empty list
list1 = [10, "Python", 3.14, True]

print(list1)
print(type(list1))
# Out:
# [10, 'Python', 3.14, True]
# <class 'list'>

# %%
tuple1 = tuple(list1)

print(tuple1)
print(type(tuple1))
# Out:
# (10, 'Python', 3.14, True)
# <class 'tuple'>

# %%
tuple1 = (1, 2, 3, "Biology", False)

print(tuple1)
print(type(tuple1))
# Out:
# (1, 2, 3, 'Biology', False)
# <class 'tuple'>

# %%
list2 = list(tuple1)

print(list2)
print(type(list2))
# Out:
# [1, 2, 3, 'Biology', False]
# <class 'list'>

# %%
list1 = ["Python", 12, 5.6, "Molecular Biology"]

print(list1)
print(len(list1))
# Out:
# ['Python', 12, 5.6, 'Molecular Biology']
# 4

# %%
string1 = "Python for my Molecular Biology course"

print(string1)
print(len(string1))
# Out:
# Python for my Molecular Biology course
# 38

# %%
string1 = "Python"

# convert to the list of characters
list_from_string1 = list(string1)
print(list_from_string1)
print(len(list_from_string1))

# convert to tuple of characters
tuple_from_string1 = tuple(string1)
print(tuple_from_string1)
print(len(tuple_from_string1))
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']
# 6
# ('P', 'y', 't', 'h', 'o', 'n')
# 6

# %%
# From list
recovered_from_list = "".join(list_from_string1)
print("Recovered string from list:", recovered_from_list)

# From tuple
recovered_from_tuple = "".join(tuple_from_string1)
print("Recovered string from tuple:", recovered_from_tuple)
# Out:
# Recovered string from list: Python
# Recovered string from tuple: Python

# %%
string1 = "Python"

# Split into list (whole word as an element)
list2_from_string1 = string1.split()
print(list2_from_string1)

# Convert list to tuple
tuple2_from_list2 = tuple(list2_from_string1)
print(tuple2_from_list2)
# Out:
# ['Python']
# ('Python',)

# %%
recovered_from_list2 = "".join(list2_from_string1)
print("Recovered string from list2:", recovered_from_list2)

recovered_from_tuple2 = "".join(tuple2_from_list2)
print("Recovered string from tuple2:", recovered_from_tuple2)
# Out:
# Recovered string from list2: Python
# Recovered string from tuple2: Python

# %%
string2 = "I love Python"

# %%
# Split sentence into words
list3_from_string2 = string2.split()
print(list3_from_string2)

# Convert to tuple
tuple3_from_list3 = tuple(list3_from_string2)
print(tuple3_from_list3)
# Out:
# ['I', 'love', 'Python']
# ('I', 'love', 'Python')

# %%
# Recover from list
recovered_from_list3 = " ".join(list3_from_string2)
print("Recovered string from list3:", recovered_from_list3)

# Recover from tuple
recovered_from_tuple3 = " ".join(tuple3_from_list3)
print("Recovered string from tuple3:", recovered_from_tuple3)
# Out:
# Recovered string from list3: I love Python
# Recovered string from tuple3: I love Python

# %%
genes = ["MYC", "C9orf72", "KRAS", "NFKBIZ"]

# %%
print(genes[2])  # Output: KRAS
# Out:
# KRAS

# %%
print(genes[-1])     # Last element  NFKBIZ
print(genes[-2])    # Second last  KRAS
# Out:
# NFKBIZ
# KRAS

# %%
position = genes.index("KRAS")
print(position)   # Output : 2
# Out:
# 2

# %%
genes.index("TP53") # Error: ValueError: 'TP53' is not in list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4693/3331500241.py in <cell line: 0>()
# ----> 1 genes.index("TP53") # Error: ValueError: 'TP53' is not in list
#
# ValueError: 'TP53' is not in list

# %%
genes = ["MYC", "C9orf72", "KRAS", "NFKBIZ", "BRCA1", "BRCA2", "HER2"]

print(genes[2:5])        # From index 2 to 4  ['KRAS', 'NFKBIZ', 'BRCA1']
print(genes[:3])         # From start to index 2  ['MYC', 'C9orf72', 'KRAS']
print(genes[3:])         # From index 3 to end  ['NFKBIZ', 'BRCA1', 'BRCA2', 'HER2']
print(genes[::2])       # Every second element  ['MYC', 'KRAS', 'BRCA1', 'HER2']
print(genes[::-1])      # Reverse the list  ['HER2', 'BRCA2', … 'MYC']
# Out:
# ['KRAS', 'NFKBIZ', 'BRCA1']
# ['MYC', 'C9orf72', 'KRAS']
# ['NFKBIZ', 'BRCA1', 'BRCA2', 'HER2']
# ['MYC', 'KRAS', 'BRCA1', 'HER2']
# ['HER2', 'BRCA2', 'BRCA1', 'NFKBIZ', 'KRAS', 'C9orf72', 'MYC']

# %%
genes = ["MYC", "C9orf72", "KRAS", "NFKBIZ",
         "KRAS", "BRCA1", "TP53", "CFTR",
         "C9orf72", "C9orf72"
         ]

# %%
occurrences = genes.count("C9orf72")
print(occurrences)
# Out:
# 3

# %%
print(genes.count("KRAS"))        # output: 2
print(genes.count("TP53"))         # output: 1
print(genes.count("GATA3"))      # output: 0
# Out:
# 2
# 1
# 0

# %%
mixed_data = ["MYC", 42, True]

# %%
print(type(mixed_data))
# Out:
# <class 'list'>

# %%
print(type(mixed_data [0]))      # Output: <class 'str'>
print(type(mixed_data [1]))      # Output: <class 'int'>
print(type(mixed_data [2]))      # Output: <class 'bool'>
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
mixed_tuple = ("MYC", 42, True)

print(type(mixed_tuple))           # <class 'tuple'>
print(type(mixed_tuple[0]))      # <class 'str'>
print(type(mixed_tuple[1]))      # <class 'int'>
print(type(mixed_tuple[2]))      # <class 'bool'>
# Out:
# <class 'tuple'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
# Initial list of gene names
list_genes = ["MYC", "C9orf72", "KRAS"]

# %%
new_gene = "NFKBIZ"

# Create a new list by concatenating
list_genes_new = list_genes + [new_gene]
print(list_genes_new)
# Out:
# ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ']

# %%
print(list_genes)
# Output: ['MYC', 'C9orf72', 'KRAS']
# Out:
# ['MYC', 'C9orf72', 'KRAS']

# %%
# Create a new list by splicing
list_genes_new2 = list_genes[0:1] + [new_gene] + list_genes[1:]
print(list_genes_new2)
# Out:
# ['MYC', 'NFKBIZ', 'C9orf72', 'KRAS']

# %%
list_genes.append(new_gene)
print(list_genes)
# Out:
# ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ']

# %%
new_list = list_genes.append(new_gene)

# %%
list_genes = ["MYC", "C9orf72", "KRAS"]      # reset original list
new_gene = "NFKBIZ"
list_genes.insert(1, new_gene)
print(list_genes)
# Out:
# ['MYC', 'NFKBIZ', 'C9orf72', 'KRAS']

# %%
list_genes = ["MYC", "C9orf72", "KRAS"]

# %%
new_genes = ["NFKBIZ", "BRCA1"]

# %%
list_genes_new = list_genes + new_genes
print(list_genes_new)
# Out:
# ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ', 'BRCA1']

# %%
print(list_genes)
# Output: ['MYC', 'C9orf72', 'KRAS']
# Out:
# ['MYC', 'C9orf72', 'KRAS']

# %%
list_genes_new2 = list_genes[0:1] + new_genes + list_genes[1:]
print(list_genes_new2)
# Out:
# ['MYC', 'NFKBIZ', 'BRCA1', 'C9orf72', 'KRAS']

# %%
list_genes = ["MYC", "C9orf72", "KRAS"]    # reset original list
new_genes = ["NFKBIZ", "BRCA1"]
list_genes.extend(new_genes)
print(list_genes)
# Out:
# ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ', 'BRCA1']

# %%
result = list_genes.extend(new_genes)
print(result)    # None
# Out:
# None

# %%
list_genes = ["MYC", "C9orf72", "KRAS"]    # reset original list
new_genes = ["NFKBIZ", "BRCA1"]
list_genes[1:1] = new_genes
print(list_genes)
# Out:
# ['MYC', 'NFKBIZ', 'BRCA1', 'C9orf72', 'KRAS']

# %%
tuple_genes = ('MYC', 'C9orf72', 'KRAS')
new_gene = ('NFKBIZ',)

# %%
tuple_genes.append(new_gene)    #  AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4693/554249525.py in <cell line: 0>()
# ----> 1 tuple_genes.append(new_gene)    #  AttributeError
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple_genes_new = tuple_genes + new_gene
print(tuple_genes_new) # ('MYC', 'C9orf72', 'KRAS', 'NFKBIA')
# Out:
# ('MYC', 'C9orf72', 'KRAS', 'NFKBIZ')

# %%
genes = ['MYC', 'C9orf72', 'KRAS']
new_genes = ['NFKBIZ', 'BRCA1']

# %%
genes.extend(new_genes)
print(genes) # ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ', 'BRCA1']
# Out:
# ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ', 'BRCA1']

# %%
genes = ['MYC', 'C9orf72', 'KRAS']
genes.append(new_genes)
print(genes) # ['MYC', 'C9orf72', 'KRAS', ['NFKBIA', 'BRCA1']]
# Out:
# ['MYC', 'C9orf72', 'KRAS', ['NFKBIZ', 'BRCA1']]

# %%
data = [
    ['MYC', 'C9orf72', 'KRAS'],
    [5, 10, 15],
    [True, False, True]
  ]

# %%
print(data[0][0])     # 'MYC'
print(data[1][1])     # 10
print(data[2][2])     # True
# Out:
# MYC
# 10
# True

# %%
container = [
    ['MYC', ['KRAS', 'BRCA1']],
    [5, 10, 15],
    [True, False, True]
  ]

# %%
print(container[0][1][1]) # 'BRCA1'
# Out:
# BRCA1

# %%
genes = ['MYC', 'C9orf72', 'KRAS']

# %%
print("Value:", genes)
print("Address:", id(genes))
# Out:
# Value: ['MYC', 'C9orf72', 'KRAS']
# Address: 138664766142208

# %%
copy_value = genes.copy()

# %%
copy_address = genes

# %%
print("Original address:", id(genes))
print("Copy by value address:", id(copy_value))
print("Copy by address address:", id(copy_address))
# Out:
# Original address: 138664766142208
# Copy by value address: 138664544788672
# Copy by address address: 138664766142208

# %%
new_gene = 'NFKBIZ'
genes.append(new_gene)

# %%
print("Original address:", genes)
print("Copy by value:", copy_value)
print("Copy by address:", copy_address)
# Out:
# Original address: ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ']
# Copy by value: ['MYC', 'C9orf72', 'KRAS']
# Copy by address: ['MYC', 'C9orf72', 'KRAS', 'NFKBIZ']

# %%
import copy
deep_clone = copy.deepcopy(genes)

# %%
# Let’s create a tuple of genes
tuple_genes = ("BRCA1", "TP53", "MYC")

# Attempting to copy by value (similar to lists)
tuple_genes_copy_value = tuple_genes.copy()   # X This will raise an error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4693/1494018959.py in <cell line: 0>()
#       3
#       4 # Attempting to copy by value (similar to lists)
# ----> 5 tuple_genes_copy_value = tuple_genes.copy()   # X This will raise an error
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
tuple_genes_copy_address = tuple_genes   # This works

# %%
# Original tuple
tuple_genes = ("BRCA1", "TP53", "MYC")

# Convert to list
gene_list = list(tuple_genes)

# Modify
gene_list.append("NFKBIZ")

# Convert back to tuple
tuple_gene_modified = tuple(gene_list)

print(tuple_gene_modified)
# Out:
# ('BRCA1', 'TP53', 'MYC', 'NFKBIZ')

# %%
genes = ["BRCA1", "C9orf72", "KRAS", "MYC", "NFKBIZ"]

# %%
genes = ["BRCA1", "C9orf72", "KRAS", "MYC", "NFKBIZ"]
genes_copy = genes.copy()
deleted_gene = genes_copy.pop()  # deletes the last element
print("Deleted:", deleted_gene)
print("After deletion:", genes_copy)
# Out:
# Deleted: NFKBIZ
# After deletion: ['BRCA1', 'C9orf72', 'KRAS', 'MYC']

# %%
genes_copy = genes.copy()
deleted_gene = genes_copy.pop(1)  # deletes value at index 1
print("Deleted:", deleted_gene)
print("After deletion:", genes_copy)
# Out:
# Deleted: C9orf72
# After deletion: ['BRCA1', 'KRAS', 'MYC', 'NFKBIZ']

# %%
genes_copy = genes.copy()
del genes_copy[2]  # delete the element at index 2
print("After deletion:", genes_copy)
# Out:
# After deletion: ['BRCA1', 'C9orf72', 'MYC', 'NFKBIZ']

# %%
genes = ["BRCA1", "C9orf72", "KRAS", "MYC", "NFKBIZ"]
genes_copy = genes.copy()
genes_copy.remove("MYC")
print("After deletion:", genes_copy)
# Out:
# After deletion: ['BRCA1', 'C9orf72', 'KRAS', 'NFKBIZ']

# %%
genes_dup = ["BRCA1", "MYC", "KRAS", "MYC"]
genes_dup.remove("MYC")
print(genes_dup)
# Out:
# ['BRCA1', 'KRAS', 'MYC']

# %%
genes_dup = [gene for gene in genes_dup if gene != "MYC"]

# %%
genes_tuple = ("BRCA1", "C9orf72", "KRAS")
# del genes_tuple[1]          X This will raise an error
# genes_tuple.pop()           X AttributeError
# genes_tuple.remove('KRAS')   X AttributeError

# %%
new_tuple = genes_tuple[:1] + genes_tuple[2:]
print(new_tuple)      # ('BRCA1', 'KRAS')
# Out:
# ('BRCA1', 'KRAS')

# %%
del genes

# %%
genes_copy = ["BRCA1", "KRAS"]
genes_copy.clear()
print(genes_copy)
# Out:
# []

# %%
chars = ['c', 'b', 'a', 'd']

# %%
genes = ['BRCA1', 'MYC', 'NFKBIZ', 'KRAS', 'C9orf72', 'MYC']
genes_sorted = sorted(genes)
print("Original list:", genes)
print("Sorted list:", genes_sorted)
# Out:
# Original list: ['BRCA1', 'MYC', 'NFKBIZ', 'KRAS', 'C9orf72', 'MYC']
# Sorted list: ['BRCA1', 'C9orf72', 'KRAS', 'MYC', 'MYC', 'NFKBIZ']

# %%
genes_sorted_desc = sorted(genes, reverse=True)
print("Descending order:", genes_sorted_desc)
# Out:
# Descending order: ['NFKBIZ', 'MYC', 'MYC', 'KRAS', 'C9orf72', 'BRCA1']

# %%
descending_alt = genes_sorted[::-1]
print("Reversed list (descending):", descending_alt)
# Out:
# Reversed list (descending): ['NFKBIZ', 'MYC', 'MYC', 'KRAS', 'C9orf72', 'BRCA1']

# %%
genes = ['BRCA1', 'MYC', 'NFKBIZ', 'KRAS', 'C9orf72', 'MYC']
genes_copy = genes.copy()
print("Before sort:", genes_copy)
genes_copy.sort()
print("After sort:", genes_copy)
# Out:
# Before sort: ['BRCA1', 'MYC', 'NFKBIZ', 'KRAS', 'C9orf72', 'MYC']
# After sort: ['BRCA1', 'C9orf72', 'KRAS', 'MYC', 'MYC', 'NFKBIZ']

# %%
genes_copy = genes.copy()
genes_copy.sort(reverse=True)
print("Descending sort:", genes_copy)      # ['NFKBIZ', 'MYC', 'MYC', 'KRAS', 'C9orf72 ', 'BRCA1']
# Out:
# Descending sort: ['NFKBIZ', 'MYC', 'MYC', 'KRAS', 'C9orf72', 'BRCA1']

# %%
genes_tuple = ('BRCA1', 'MYC', 'NFKBIA', 'KRAS')
sorted_list = sorted(genes_tuple)
sorted_tuple = tuple(sorted_list)
print("Original tuple:", genes_tuple)
print("Sorted tuple:", sorted_tuple)
# Out:
# Original tuple: ('BRCA1', 'MYC', 'NFKBIA', 'KRAS')
# Sorted tuple: ('BRCA1', 'KRAS', 'MYC', 'NFKBIA')

# %%
genes = ['BRCA1', 'MYC', 'NFKBIA', 'KRAS', 'C9orf72', 'MYC']

# %%
print('MYC' in genes)
print('MYC' not in genes)
print('BRCA2' in genes)
print('BRCA2' not in genes)
# Out:
# True
# False
# False
# True

# %%
print('M' in genes)              # False
print('KR' in genes)            # False
print('KRAS' in genes)       # True
# Out:
# False
# False
# True

# %%
genes_name = 'NFKBIZ'

# %%
print('NF' in genes_name)              # True
print('CF' in genes_name)              # False
print('NF' not in genes_name)        # False
# Out:
# True
# False
# False

# %%
expression_values = [12, 34, 56, 78, 90]

print(60 in expression_values)                 # False
print(60 not in expression_values)           # True
print(34 in expression_values)                 # True
print(34 not in expression_values)           # False
# Out:
# False
# True
# True
# False

# %%
genes = ["BRCA1", "TP53", "KRAS", "MYC"]
expression_values = [20, -15, 40.6, 14.0]

# %%
max_expression = max(expression_values)
print(max_expression)             # Output: 40.6
# Out:
# 40.6

# %%
min_expression = min(expression_values)
print(min_expression)             # -15
# Out:
# -15

# %%
max_gene = max(genes)
min_gene = min(genes)

print("Maximum gene:", max_gene)
print("Minimum gene:", min_gene)
# Out:
# Maximum gene: TP53
# Minimum gene: BRCA1

# %%
print(sorted(genes))
# Out:
# ['BRCA1', 'KRAS', 'MYC', 'TP53']

# %%
expression_values = [20, -15, 40.6, 14.0]
total_expression = sum(expression_values)
print(total_expression)
# Out:
# 59.6

# %%
genes = ["BRCA1", "TP53", "KRAS", "MYC"]
sum(genes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4693/4171318315.py in <cell line: 0>()
#       1 genes = ["BRCA1", "TP53", "KRAS", "MYC"]
# ----> 2 sum(genes)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
nested_genes = [["BRCA1", "TP53"], ["KRAS", "MYC"]]

# %%
['BRCA1', 'TP53', 'KRAS', 'MC']
# Out:
# ['BRCA1', 'TP53', 'KRAS', 'MC']

# %%
nested_genes = [["BRCA1", "TP53"], ["KRAS", "MYC"]]
flattened_genes = sum(nested_genes, [])
print(flattened_genes)
# Out:
# ['BRCA1', 'TP53', 'KRAS', 'MYC']

# %%
python_class_attendance = [True, False, True, True]

# %%
result_all = all(python_class_attendance)
print(result_all)
# Out:
# False

# %%
result_any = any(python_class_attendance)
print(result_any)
# Out:
# True

# %%
day_two = [True, True, True, True]
print(all(day_two))     # True
print(any(day_two))   # True
# Out:
# True
# True

# %%
day_three = [False, False, False, False]
print(all(day_three))     # False
print(any(day_three))   # False
# Out:
# False
# False

# %%
attendance_tuple = (True, False, True)
print(all(attendance_tuple))        #False
print(any(attendance_tuple))      #True
# Out:
# False
# True

# %%
gene_list = ["MYC", "BRCA1", "C9orf72", "TP53"]
expression_list = [20, 30, 15, 10]

# %%
gene_information = list(zip(gene_list, expression_list))
print(gene_information)
# Out:
# [('MYC', 20), ('BRCA1', 30), ('C9orf72', 15), ('TP53', 10)]

# %%
gene_information = [('MYC', 20), ('BRCA1', 30), ('C9orf72', 15), ('TP53', 10)]
gene_list, expression_list = zip(*gene_information)
print(gene_list)
print(expression_list)
# Out:
# ('MYC', 'BRCA1', 'C9orf72', 'TP53')
# (20, 30, 15, 10)

# %%
gene_list = list(gene_list)
expression_list = list(expression_list)
