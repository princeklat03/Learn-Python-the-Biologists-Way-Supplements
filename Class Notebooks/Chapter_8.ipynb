# %%
a = range(6)    # generates numbers from 0 to 5
print(list(a))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list_num = [num ** 3 for num in a]
print(list_num)
# Out:
# [0, 1, 8, 27, 64, 125]

# %%
student_names = ["Anna", "Peter", "Louis"]

# %%
email_students = [x.lower() + "@gmail.com" for x in student_names]
print(email_students)
# Out:
# ['anna@gmail.com', 'peter@gmail.com', 'louis@gmail.com']

# %%
student_names = ["Anna", "Peter", "Louis", "John"]
missing_indices = [1, 3]

# %%
missing_students = [student_names[i] for i in missing_indices]
print(missing_students)
# Out:
# ['Peter', 'John']

# %%
for variable in iterable:
  # indented block of code

# %%
protein_list = ["Insulin", "Actin", "Fibrinogen"]

# %%
for protein in protein_list:
    print(protein, "is a protein.")
# Out:
# Insulin is a protein.
# Actin is a protein.
# Fibrinogen is a protein.

# %%
for protein in protein_list:
    print(protein, "is a protein.")
    print("-----")
# Out:
# Insulin is a protein.
# -----
# Actin is a protein.
# -----
# Fibrinogen is a protein.
# -----

# %%
for protein in protein_list:
    print(protein, "is a protein.")
print("-----")
# Out:
# Insulin is a protein.
# Actin is a protein.
# Fibrinogen is a protein.
# -----

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for letter in "I love Python":
    print(letter)
# Out:
# I
#
# l
# o
# v
# e
#
# P
# y
# t
# h
# o
# n

# %%
gene_list = ["MYC", "NFKBIZ", "BRCA1"]
expression_list = [-20, 80, 10]

# %%
for i in range(len(gene_list)):
    print(f"Gene {gene_list[i]} shows an expression of {expression_list[i]}")
# Out:
# Gene MYC shows an expression of -20
# Gene NFKBIZ shows an expression of 80
# Gene BRCA1 shows an expression of 10

# %%
for gene in gene_list:
    print(gene)
# Out:
# MYC
# NFKBIZ
# BRCA1

# %%
for i in range(len(gene_list)):
    print(gene_list[i])
# Out:
# MYC
# NFKBIZ
# BRCA1

# %%
for item in outer_iterable:
  # first level of indentation
    for element in inner_iterable:
      # second level of indentation
      # operations using item and element
      # back to first level: still inside outer loop
# no indentation: outside both loops
# Out:
#   File "/tmp/ipykernel_1118/1872287417.py", line 7
#     # no indentation: outside both loops
#                                         ^
# SyntaxError: incomplete input

# %%
DNA_sequence = [
    ["A", "T", "C"],
    ["A", "A", "T", "T", "G"],
    ["C", "A"],
    ["G", "G", "A", "T", "T", "C"]
    ]

# %%
length_list = []

# %%
DNA_sequence = [
    ["A", "T", "C"],
    ["A", "A", "T", "T", "G"],
    ["C", "A"],
    ["G", "G", "A", "T", "T", "C"]
    ]

length_list = []

for row in DNA_sequence:
    count = 0
    for base in row:
        count = count + 1
    length_list.append(count)

print("Lengths of nested lists:", length_list)
# Out:
# Lengths of nested lists: [3, 5, 2, 6]

# %%
while condition:
  # code block
# Out:
#   File "/tmp/ipykernel_1118/679998173.py", line 2
#     # code block
#                 ^
# SyntaxError: incomplete input

# %%
DNA = "ATTCGATGCA"

# %%
for index in range(len(DNA)):
    print(f"Base at position {index} is {DNA[index]}")
# Out:
# Base at position 0 is A
# Base at position 1 is T
# Base at position 2 is T
# Base at position 3 is C
# Base at position 4 is G
# Base at position 5 is A
# Base at position 6 is T
# Base at position 7 is G
# Base at position 8 is C
# Base at position 9 is A

# %%
DNA = "ATTCGATGCA"
i = 0

while i < len(DNA):
    print(f"Base at position {i} is {DNA[i]}")
    i = i + 1   # important!
# Out:
# Base at position 0 is A
# Base at position 1 is T
# Base at position 2 is T
# Base at position 3 is C
# Base at position 4 is G
# Base at position 5 is A
# Base at position 6 is T
# Base at position 7 is G
# Base at position 8 is C
# Base at position 9 is A

# %%
DNA2 = "ATTCGATGCANCTA"

# %%
DNA2 = "ATTCGATGCANCTA"
i = 0

while True:  # Infinite loop on purpose
    if DNA2[i] == "N":
        print("Unknown base found at index", i)
        break
    else:
        i = i + 1
        continue
# Out:
# Unknown base found at index 10

# %%
while condition1:
  while condition2:
    # inner loop
# Out:
#   File "/tmp/ipykernel_1118/1944578739.py", line 3
#     # inner loop
#                 ^
# SyntaxError: incomplete input
