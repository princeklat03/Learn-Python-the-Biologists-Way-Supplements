# %%
"""
In-class Notebook for Chapter 9
Learn Python the Biologist's Way

This notebook contains the Python code examples
demonstrated throughout Chapter 9.

The notebook is provided as a companion resource
to help readers practice, experiment, and reproduce
the examples discussed in the book.

The book purchase link and additional resources are
available on the GitHub repository landing page.

Author: Dr. Prince Kumar Lat
"""

print('Welcome to Chapter 9')

# %%
print(2 ==2)
print(2 ==3)

# %%
print(2 < 3)
print(2 < 1)

print(2 <= 2)
print(2 <= 1)

print(3 > 2)
print(3 > 4)

print(8 >= 8)
print(8 >= 9)

# %%
print(2 != 3)
print(2 != 2)

# %%
DNA = "ATTACTGCCG"

# %%
print(DNA.startswith("AT"))
print(DNA.startswith("CG"))

print(DNA.endswith("CCG"))
print(DNA.endswith("CGT"))

# %%
gene_list = ["MYC", "NFKB2", "TP53"]

print("MYC" in gene_list)
print("BRCA1" in gene_list)
print("BRCA1" not in gene_list)

# %%
print(1 < 2 or 2 > 3)

# %%
print(1 > 2 or 2 > 3)

# %%
print(1 < 2 and 2 < 3)
print(1 < 2 and 2 > 3)

# %%
print(not (2 < 3))
print(not (2 > 3))

# %%
print(bool(0))
print(bool(100))
print(bool(""))
print(bool("ATG"))
print(bool(None))

# %%
# if condition:
#     # executes when condition is True
#     # if block codes
# else:
#     # executes when condition is False
#     # else block codes

# %%
# if condition1:
#     # executes when condition1 is True
# elif condition2:
#     # executes when condition2 is True
# elif condition3:
#     # executes when condition3 is True
# else:
#     # executes when none of the above conditions are True

# %%
gene_expression = [20, 10, 2, 30, 55, 120, 150, 200]

# %%
for expression in gene_expression:
    print(f"Gene with expression value: {expression}")
    if expression < 20:
        print("LOW expression")
        print()
    else:
        print("HIGH expression")
        print()

# %%
for expression in gene_expression:
    if expression < 20:
        print("Low expression")
    elif expression >= 20 and expression < 100:
        print("Moderate expression")
    else:
        print("High expression")

# %%
sequence = "ATGCGTACGTAG"
start_codon = "ATG"

if sequence.startswith(start_codon):
    if len(sequence) % 3 == 0:
        print(f"Sequence starts with a start codon.",
                f"Sequence is a valid coding sequence.")
    else:
        print(f"Sequence starts with a start codon,",
                f"but it is NOT a valid coding sequence.")
else:
      print(f"Sequence does NOT start with a start codon,")

# %%
x=5
if x > 3:
    print("Greater than 3")
else:
    print("Not greater than 3")
